# %% [markdown]
# <a href="https://colab.research.google.com/github/bharatkaushik2015/Python-library-practice-notes/blob/main/PandasPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Data Structures in Pandas**
#
# Two fundamental data structures used in pandas are:
#
# 1. Series: A 1-D array.
#
# 2. Data Frame: A 2-D array or two or more Series joined together

# %%
import numpy as np
import pandas as pd

# %%
# Task1
heights_A=pd.Series([176.2,158.4,167.6,156.2,161.4],index=['s1','s2','s3','s4','s5'])
print(heights_A.shape)

#Task2
weights_A=pd.Series([85.1,90.2,76.8,80.4,78.9],index=['s1','s2','s3','s4','s5'])
print(weights_A.dtypes)
# Out:
# (5,)
# float64

# %%
heights_A
# Out:
# s1    176.2
# s2    158.4
# s3    167.6
# s4    156.2
# s5    161.4
# dtype: float64

# %%
weights_A
# Out:
# s1    85.1
# s2    90.2
# s3    76.8
# s4    80.4
# s5    78.9
# dtype: float64

# %%
df_A=pd.DataFrame({'Student_height':heights_A,'Student_weight':weights_A})
df_A
# Out:
#     Student_height  Student_weight
# s1           176.2            85.1
# s2           158.4            90.2
# s3           167.6            76.8
# s4           156.2            80.4
# s5           161.4            78.9

# %% [markdown]
# Accessing Data from Pandas Data structures

# %%
# Accessing a single value
heights_A
# Out:
# s1    176.2
# s2    158.4
# s3    167.6
# s4    156.2
# s5    161.4
# dtype: float64

# %%
heights_A.loc['s1'] #explicit indexing
# Out:
# 176.2

# %%
heights_A.iloc[2]
# Out:
# 167.6

# %%
heights_A.get('s1')
# Out:
# 176.2

# %%
#Accessing a slice
heights_A[0:3] # -> works like how slicing works in list or numpy
# Out:
# s1    176.2
# s2    158.4
# s3    167.6
# dtype: float64

# %%
heights_A['s1':'s4'] # doesn't exclude result for 's4'
# Out:
# s1    176.2
# s2    158.4
# s3    167.6
# s4    156.2
# dtype: float64

# %%
heights_A.loc['s6']=170.0 #Overwrites or write a new row

# %%
heights_A.loc['s1']=176

# %%
heights_A
# Out:
# s1    176.0
# s2    158.4
# s3    167.6
# s4    156.2
# s5    161.4
# s6    170.0
# dtype: float64

# %% [markdown]
# Knowing a Series

# %%
weights_A
# Out:
# s1    85.1
# s2    90.2
# s3    76.8
# s4    80.4
# s5    78.9
# dtype: float64

# %%
# describe() gives statistical summary of data
weights_A.describe()
# Out:
# count     5.000000
# mean     82.280000
# std       5.377453
# min      76.800000
# 25%      78.900000
# 50%      80.400000
# 75%      85.100000
# max      90.200000
# dtype: float64

# %% [markdown]
# Knowing a DataFrame

# %%
df_A.info() # gives info about dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, s1 to s5
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_height  5 non-null      float64
#  1   Student_weight  5 non-null      float64
# dtypes: float64(2)
# memory usage: 292.0+ bytes

# %%
df_A.describe() # gives statistical summary of numerical fields (default)
# Out:
#        Student_height  Student_weight
# count        5.000000        5.000000
# mean       163.960000       82.280000
# std          8.073909        5.377453
# min        156.200000       76.800000
# 25%        158.400000       78.900000
# 50%        161.400000       80.400000
# 75%        167.600000       85.100000
# max        176.200000       90.200000

# %%
df_A.describe(include='all') # gives statistical summary of all fields
# Out:
#        Student_height  Student_weight
# count        5.000000        5.000000
# mean       163.960000       82.280000
# std          8.073909        5.377453
# min        156.200000       76.800000
# 25%        158.400000       78.900000
# 50%        161.400000       80.400000
# 75%        167.600000       85.100000
# max        176.200000       90.200000

# %%
df_A["label"]=["B","A","C","A","B"]

# %%
df_A.describe(include='object') # gives statistical summary of categorical fields
# Out:
#        label
# count      5
# unique     3
# top        B
# freq       2

# %% [markdown]
# **Indexing**
#
# Indexing refers to labeling data elements of a Series, a Data Frame.
#
# These labels can be utilized for selecting portion of data from any of the defined data structures.

# %%
df=pd.DataFrame([[1,2],[3,4]], columns=['a','b'])

# %%
df.index=['bharat','rahil']

# %%
df
# Out:
#         a  b
# bharat  1  2
# rahil   3  4

# %%
df.index=pd.date_range(start='1/1/2018', end='1/02/2018') # we can use date_range function to create date index

# %%
df
# Out:
#             a  b
# 2018-01-01  1  2
# 2018-01-02  3  4

# %% [markdown]
# Heirarchical Indexing

# %%
df_A
# Out:
#     Student_height  Student_weight label
# s1           176.2            85.1     B
# s2           158.4            90.2     A
# s3           167.6            76.8     C
# s4           156.2            80.4     A
# s5           161.4            78.9     B

# %%
df_A.set_index(['Student_height','Student_weight'],inplace=True)

# %%
df_A.index
# Out:
# MultiIndex([(176.2, 85.1),
#             (158.4, 90.2),
#             (167.6, 76.8),
#             (156.2, 80.4),
#             (161.4, 78.9)],
#            names=['Student_height', 'Student_weight'])

# %%
pd.bdate_range('11-Sep-2017', '17-Sep-2017', freq='2D') # works like date_range if frequency changed
# Out:
# DatetimeIndex(['2017-09-11', '2017-09-13', '2017-09-15', '2017-09-17'], dtype='datetime64[ns]', freq='2D')

# %%
pd.bdate_range('11-Sep-2017', '17-Sep-2017')
# Out:
# DatetimeIndex(['2017-09-11', '2017-09-12', '2017-09-13', '2017-09-14',
#                '2017-09-15'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# select columns

# %%
df_A
# Out:
#                               label
# Student_height Student_weight
# 176.2          85.1               B
# 158.4          90.2               A
# 167.6          76.8               C
# 156.2          80.4               A
# 161.4          78.9               B

# %%
df_A.reset_index(inplace=True)

# %%
df_A.Student_height
# Out:
# 0    176.2
# 1    158.4
# 2    167.6
# 3    156.2
# 4    161.4
# Name: Student_height, dtype: float64

# %%
df_A[["Student_height","Student_weight"]]  # Multiple columns
# Out:
#    Student_height  Student_weight
# 0           176.2            85.1
# 1           158.4            90.2
# 2           167.6            76.8
# 3           156.2            80.4
# 4           161.4            78.9

# %%
df_A.loc[:,["Student_height"]] # selecting column using explicit index
# Out:
#    Student_height
# 0           176.2
# 1           158.4
# 2           167.6
# 3           156.2
# 4           161.4

# %%
df_A.loc[:,"Student_height":"label"] # selecting all columns using explicit index
# Out:
#    Student_height  Student_weight label
# 0           176.2            85.1     B
# 1           158.4            90.2     A
# 2           167.6            76.8     C
# 3           156.2            80.4     A
# 4           161.4            78.9     B

# %%
df_A.loc[:,::2]
# Out:
#    Student_height label
# 0           176.2     B
# 1           158.4     A
# 2           167.6     C
# 3           156.2     A
# 4           161.4     B

# %%
df_A.iloc[:,0] # selecting column using implicit index
# Out:
# 0    176.2
# 1    158.4
# 2    167.6
# 3    156.2
# 4    161.4
# Name: Student_height, dtype: float64

# %%
df_A.iloc[:,[0,2]] # selecting column using implicit index
# Out:
#    Student_height label
# 0           176.2     B
# 1           158.4     A
# 2           167.6     C
# 3           156.2     A
# 4           161.4     B

# %%
df_A.iloc[:,1::]
# Out:
#    Student_weight label
# 0            85.1     B
# 1            90.2     A
# 2            76.8     C
# 3            80.4     A
# 4            78.9     B

# %% [markdown]
# Query rows by value

# %%
technologies= {
    'Courses':["Spark","PySpark","Hadoop","Python","Pandas"],
    'Fee' :[22000,25000,23000,24000,26000],
    'Duration':['30days','50days','30days', None,np.nan],
    'Discount':[1000,2300,1000,1200,2500]
          }
df = pd.DataFrame(technologies)
print("Create DataFrame:\n", df)
# Out:
# Create DataFrame:
#     Courses    Fee Duration  Discount
# 0    Spark  22000   30days      1000
# 1  PySpark  25000   50days      2300
# 2   Hadoop  23000   30days      1000
# 3   Python  24000     None      1200
# 4   Pandas  26000      NaN      2500

# %%
df.query('Courses=="Spark"')
# Out:
#   Courses    Fee Duration  Discount
# 0   Spark  22000   30days      1000

# %%
df[df["Courses"]=="Spark"]
# Out:
#   Courses    Fee Duration  Discount
# 0   Spark  22000   30days      1000

# %%
df
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  22000   30days      1000
# 1  PySpark  25000   50days      2300
# 2   Hadoop  23000   30days      1000
# 3   Python  24000     None      1200
# 4   Pandas  26000      NaN      2500

# %%
df.query('Courses in ["Spark","PySpark"]') # Querying using df.query
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  22000   30days      1000
# 1  PySpark  25000   50days      2300

# %%
df[df.Courses.isin(["Spark","PySpark"])] # querying using masking
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  22000   30days      1000
# 1  PySpark  25000   50days      2300

# %%
df
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  22000   30days      1000
# 1  PySpark  25000   50days      2300
# 2   Hadoop  23000   30days      1000
# 3   Python  24000     None      1200
# 4   Pandas  26000      NaN      2500

# %%
df.query("`Fee` >= 23000 and `Fee` <= 24000")
# Out:
#   Courses    Fee Duration  Discount
# 2  Hadoop  23000   30days      1000
# 3  Python  24000     None      1200

# %%
# column -> `` use backtick
# column value -> use '' single inverted commas
df.query("`Fee` == 25000 and `Duration` == '50days'")
# Out:
#    Courses    Fee Duration  Discount
# 1  PySpark  25000   50days      2300

# %%
#query row using apply function
df
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  22000   30days      1000
# 1  PySpark  25000   50days      2300
# 2   Hadoop  23000   30days      1000
# 3   Python  24000     None      1200
# 4   Pandas  26000      NaN      2500

# %%
# apply function: axis-0 --> index , apply function to each column
# apply function: axis-1 --> row , apply function to each row

df.apply(lambda x : x[df["Courses"].isin(["Spark","PySpark"])])
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  22000   30days      1000
# 1  PySpark  25000   50days      2300

# %%
df.apply(lambda x : x[0]) # applied to each column
# Out:
# Courses      Spark
# Fee          22000
# Duration    30days
# Discount      1000
# dtype: object

# %%
df.apply(lambda x : x[0], axis=1) # applied to each row
# Out:
# <ipython-input-54-ddae3570fc8b>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.apply(lambda x : x[0], axis=1) # applied to each row
# 0      Spark
# 1    PySpark
# 2     Hadoop
# 3     Python
# 4     Pandas
# dtype: object

# %% [markdown]
# Get cell values

# %%
df
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  22000   30days      1000
# 1  PySpark  25000   50days      2300
# 2   Hadoop  23000   30days      1000
# 3   Python  24000     None      1200
# 4   Pandas  26000      NaN      2500

# %%
df.loc[0]["Fee"]
# Out:
# 22000

# %%
df.loc[0,"Fee"]
# Out:
# 22000

# %%
df.iloc[0,1]
# Out:
# 22000

# %%
df.iloc[0][1]
# Out:
# <ipython-input-59-bce042ebbecd>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][1]
# 22000

# %%
df["Fee"].values[3], df["Fee"].values[0]
# Out:
# (24000, 22000)

# %% [markdown]
# Add New column

# %%
df
# Out:
#    Courses    Fee Duration  Discount
# 0    Spark  22000   30days      1000
# 1  PySpark  25000   50days      2300
# 2   Hadoop  23000   30days      1000
# 3   Python  24000     None      1200
# 4   Pandas  26000      NaN      2500

# %%
#Method-1
df["Net_Fee"]=df["Fee"]-df["Discount"]

# %%
df
# Out:
#    Courses    Fee Duration  Discount  Net_Fee
# 0    Spark  22000   30days      1000    21000
# 1  PySpark  25000   50days      2300    22700
# 2   Hadoop  23000   30days      1000    22000
# 3   Python  24000     None      1200    22800
# 4   Pandas  26000      NaN      2500    23500

# %%
#Method-2
df.assign(Net_Fee=df["Fee"]-df["Discount"])
# Out:
#    Courses    Fee Duration  Discount  Net_Fee
# 0    Spark  22000   30days      1000    21000
# 1  PySpark  25000   50days      2300    22700
# 2   Hadoop  23000   30days      1000    22000
# 3   Python  24000     None      1200    22800
# 4   Pandas  26000      NaN      2500    23500

# %%
# discount percent
df.assign(Discount_per=lambda x:(x.Discount/x.Fee)*100)
# Out:
#    Courses    Fee Duration  Discount  Net_Fee  Discount_per
# 0    Spark  22000   30days      1000    21000      4.545455
# 1  PySpark  25000   50days      2300    22700      9.200000
# 2   Hadoop  23000   30days      1000    22000      4.347826
# 3   Python  24000     None      1200    22800      5.000000
# 4   Pandas  26000      NaN      2500    23500      9.615385

# %%
#Method-3 Syntax: df.insert(loc position where you want column, "column_name", [values])
df.insert(3, "Constant",[i for i in range(5)])

# %%
df
# Out:
#    Courses    Fee Duration  Constant  Discount  Net_Fee
# 0    Spark  22000   30days         0      1000    21000
# 1  PySpark  25000   50days         1      2300    22700
# 2   Hadoop  23000   30days         2      1000    22000
# 3   Python  24000     None         3      1200    22800
# 4   Pandas  26000      NaN         4      2500    23500

# %% [markdown]
# Rename Column

# %%
# Method-1
df.columns
# Out:
# Index(['Courses', 'Fee', 'Duration', 'Constant', 'Discount', 'Net_Fee'], dtype='object')

# %%
df.columns.values[3]="integer"

# %%
df
# Out:
#    Courses    Fee Duration  integer  Discount  Net_Fee
# 0    Spark  22000   30days        0      1000    21000
# 1  PySpark  25000   50days        1      2300    22700
# 2   Hadoop  23000   30days        2      1000    22000
# 3   Python  24000     None        3      1200    22800
# 4   Pandas  26000      NaN        4      2500    23500

# %%
# Method-2 rename method with columns argument & creates a copy, hence provided inplace true
df.rename(columns={"Fee":"fee"}, inplace=True)

# %% [markdown]
# Dropping rows

# %%
df
# Out:
#    Courses    fee Duration  integer  Discount  Net_Fee
# 0    Spark  22000   30days        0      1000    21000
# 1  PySpark  25000   50days        1      2300    22700
# 2   Hadoop  23000   30days        2      1000    22000
# 3   Python  24000     None        3      1200    22800
# 4   Pandas  26000      NaN        4      2500    23500

# %%
#Method syntax: df.drop(index=index_num)
df.drop(index=2, inplace=True)

# %%
df
# Out:
#    Courses    fee Duration  integer  Discount  Net_Fee
# 0    Spark  22000   30days        0      1000    21000
# 1  PySpark  25000   50days        1      2300    22700
# 3   Python  24000     None        3      1200    22800
# 4   Pandas  26000      NaN        4      2500    23500

# %% [markdown]
# Dropping column

# %%
df
# Out:
#    Courses    fee Duration  integer  Discount  Net_Fee
# 0    Spark  22000   30days        0      1000    21000
# 1  PySpark  25000   50days        1      2300    22700
# 3   Python  24000     None        3      1200    22800
# 4   Pandas  26000      NaN        4      2500    23500

# %%
# Method: syntax df.drop(columns="value" or list of multiple values)
df.drop(columns="integer",inplace=True)
df
# Out:
#    Courses    fee Duration  Discount  Net_Fee
# 0    Spark  22000   30days      1000    21000
# 1  PySpark  25000   50days      2300    22700
# 3   Python  24000     None      1200    22800
# 4   Pandas  26000      NaN      2500    23500

# %% [markdown]
# Cast Data Type
# 1. Applying the .astype() method to convert data types directly, specifying the desired dtype.
# 2. Utilizing the .to_numeric() function to coerce object types into numeric types, with options for handling errors and coercing strings.
# 3. Using the infer_objects() method to automatically infer and convert data types.
# 4. Employing the as_type() method to convert data types with specific parameters like nullable integers.
# 5. Utilizing custom functions or mapping techniques for more complex type conversions.

# %%
df.insert(5, "categorical",[i for i in range(4)])  # inplace operation by default

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Courses      4 non-null      object
#  1   fee          4 non-null      int64
#  2   Duration     2 non-null      object
#  3   Discount     4 non-null      int64
#  4   Net_Fee      4 non-null      int64
#  5   categorical  4 non-null      int64
# dtypes: int64(4), object(2)
# memory usage: 224.0+ bytes

# %%
# Method: syntax -> provide dictionary to astype method
df=df.astype({"categorical" : object})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Courses      4 non-null      object
#  1   fee          4 non-null      int64
#  2   Duration     2 non-null      object
#  3   Discount     4 non-null      int64
#  4   Net_Fee      4 non-null      int64
#  5   categorical  4 non-null      object
# dtypes: int64(3), object(3)
# memory usage: 224.0+ bytes

# %%
# Convert catgorical to numeric using pd.to_numeric
df["categorical"]=pd.to_numeric(df["categorical"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Courses      4 non-null      object
#  1   fee          4 non-null      int64
#  2   Duration     2 non-null      object
#  3   Discount     4 non-null      int64
#  4   Net_Fee      4 non-null      int64
#  5   categorical  4 non-null      int64
# dtypes: int64(4), object(2)
# memory usage: 224.0+ bytes

# %% [markdown]
# Count number of rows

# %%
# Optimized method (because other methods are very slow)
# Method 1
print(df.shape[0])
# Method 2
print(len(df.index))
# Out:
# 4
# 4

# %%
# give count of all non-Nan values for each column
df.count()
# Out:
# Courses        4
# fee            4
# Duration       2
# Discount       4
# Net_Fee        4
# categorical    4
# dtype: int64

# %% [markdown]
# Apply Function

# %%
# apply function: axis-0 --> index , apply function to each column
# apply function: axis-1 --> row , apply function to each row
df
# Out:
#    Courses    fee Duration  Discount  Net_Fee  categorical
# 0    Spark  22000   30days      1000    21000            0
# 1  PySpark  25000   50days      2300    22700            1
# 3   Python  24000     None      1200    22800            2
# 4   Pandas  26000      NaN      2500    23500            3

# %%
def commission(x):
    x["commission"] = x["Net_Fee"]*0.05
    return x["commission"]

df["commission"]=df.apply(commission, axis=1)
df
# Out:
#    Courses    fee Duration  Discount  Net_Fee  categorical  commission
# 0    Spark  22000   30days      1000    21000            0      1050.0
# 1  PySpark  25000   50days      2300    22700            1      1135.0
# 3   Python  24000     None      1200    22800            2      1140.0
# 4   Pandas  26000      NaN      2500    23500            3      1175.0

# %%
# In series no need to mention axis
df["categorical"].apply(lambda x:x+1)
# Out:
# 0    1
# 1    2
# 3    3
# 4    4
# Name: categorical, dtype: int64

# %% [markdown]
# Column values as list

# %%
# wrong method
arr=df.columns
type(arr)
# Out:
# pandas.core.indexes.base.Index

# %%
# Method 1
arr1=df.columns.tolist()
arr1
# Out:
# ['Courses',
#  'fee',
#  'Duration',
#  'Discount',
#  'Net_Fee',
#  'categorical',
#  'commission']

# %%
# method 2
arr2=list(df.columns)
arr2
# Out:
# ['Courses',
#  'fee',
#  'Duration',
#  'Discount',
#  'Net_Fee',
#  'categorical',
#  'commission']

# %%
# method 3
df.columns.values.tolist()
# Out:
# ['Courses',
#  'fee',
#  'Duration',
#  'Discount',
#  'Net_Fee',
#  'categorical',
#  'commission']

# %% [markdown]
# Data Aggregation in pandas

# %%
# Group by Function
df1=pd.DataFrame({"Name":['A','B','C','A','B','C'],"Marks":[0,1,2,3,4,5]})
df1
# Out:
#   Name  Marks
# 0    A      0
# 1    B      1
# 2    C      2
# 3    A      3
# 4    B      4
# 5    C      5

# %%
# creates a group by object
df1.groupby('Name')

# %%
df1.groupby('Name').sum()
# Out:
#       Marks
# Name
# A         3
# B         5
# C         7

# %%
df2 = df1.groupby('Name').mean() # Notice after group by column 'Name' is set to index

# %%
df2.index
df2.reset_index(inplace=True)

# %%
df2
# Out:
#   Name  Marks
# 0    A    1.5
# 1    B    2.5
# 2    C    3.5

# %% [markdown]
# Advance groupby functions
# 1. aggregate func
# 2. filter
# 3. transform

# %%
# aggregate
df1.groupby('Name').aggregate(['sum','mean'])
# Out:
#      Marks
#        sum mean
# Name
# A        3  1.5
# B        5  2.5
# C        7  3.5

# %%
# filter -> inside lambda it's calculating group mean and filtering based on our condition
df1.groupby('Name').filter(lambda x:x['Marks'].mean()>2)
# Out:
#   Name  Marks
# 1    B      1
# 2    C      2
# 4    B      4
# 5    C      5

# %%
# Transform -> inside lambda it will calculate group aggregation but result will have same number of rows as main df before group by
# and groupby key will not be present
df1.groupby('Name').transform(lambda x:x.sum())
# Out:
#    Marks
# 0      3
# 1      5
# 2      7
# 3      3
# 4      5
# 5      7

# %% [markdown]
# Joining Data Frames
# 1. df.join
# 2. pd.merge
# 3. concat

# %%
# In pandas join is performed on row indices while in SQL join happens based on column
# syntax: df.join(dataframe or series, on='column_name', how='left,right'(by default left))
technologies = {
    'Courses':["Spark","PySpark","Python","pandas"],
    'Fee' :[20000,25000,22000,30000],
    'Duration':['30days','40days','35days','50days'],
              }
index_labels=['r1','r2','r3','r4']
df1 = pd.DataFrame(technologies,index=index_labels)
print("First DataFrame:\n", df1)
technologies2 = {
    'Courses':["Spark","Java","Python","Go"],
    'Discount':[2000,2300,1200,2000]
              }
index_labels2=['r1','r6','r3','r5']
df2 = pd.DataFrame(technologies2,index=index_labels2)
print("Second DataFRame:\n", df2)
# Out:
# First DataFrame:
#      Courses    Fee Duration
# r1    Spark  20000   30days
# r2  PySpark  25000   40days
# r3   Python  22000   35days
# r4   pandas  30000   50days
# Second DataFRame:
#     Courses  Discount
# r1   Spark      2000
# r6    Java      2300
# r3  Python      1200
# r5      Go      2000

# %%
df1.join(df2,rsuffix='_df1',lsuffix='_df2',how='left')
# Out:
#    Courses_df2    Fee Duration Courses_df1  Discount
# r1       Spark  20000   30days       Spark    2000.0
# r2     PySpark  25000   40days         NaN       NaN
# r3      Python  22000   35days      Python    1200.0
# r4      pandas  30000   50days         NaN       NaN

# %%
df1.join(df2,rsuffix='_df1',lsuffix='_df2',how='inner')
# Out:
#    Courses_df2    Fee Duration Courses_df1  Discount
# r1       Spark  20000   30days       Spark      2000
# r3      Python  22000   35days      Python      1200

# %%
# Merge -> better than join don't even provide extra column how='inner' by default
# syntax-1
pd.merge(df1,df2,on='Courses')
# Out:
#   Courses    Fee Duration  Discount
# 0   Spark  20000   30days      2000
# 1  Python  22000   35days      1200

# %%
# syntax-2
df1.merge(df2,on='Courses')
# Out:
#   Courses    Fee Duration  Discount
# 0   Spark  20000   30days      2000
# 1  Python  22000   35days      1200

# %%
# concat -> default axis value 0 , on top of each other
pd.concat([df1,df2], axis=0)
# Out:
#     Courses      Fee Duration  Discount
# r1    Spark  20000.0   30days       NaN
# r2  PySpark  25000.0   40days       NaN
# r3   Python  22000.0   35days       NaN
# r4   pandas  30000.0   50days       NaN
# r1    Spark      NaN      NaN    2000.0
# r6     Java      NaN      NaN    2300.0
# r3   Python      NaN      NaN    1200.0
# r5       Go      NaN      NaN    2000.0

# %%
pd.concat([df1,df2], axis=1) # axis =1 side by side
# Out:
#     Courses      Fee Duration Courses  Discount
# r1    Spark  20000.0   30days   Spark    2000.0
# r2  PySpark  25000.0   40days     NaN       NaN
# r3   Python  22000.0   35days  Python    1200.0
# r4   pandas  30000.0   50days     NaN       NaN
# r6      NaN      NaN      NaN    Java    2300.0
# r5      NaN      NaN      NaN      Go    2000.0

# %% [markdown]
# Restructuring Data
# 1. pd.melt()
# 2. pd.pivot()
# 3. pd.pivot_table()
# 4. pd.cut()
# 5. pd.qcut()
# 6. pd.crosstab()

# %%
# melt function -- unpivots the table
df_melt = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5},
                   'C': {0: 2, 1: 4, 2: 6}})
df_melt
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6

# %%
df_melt.melt(id_vars=['A'], value_vars=['B'], var_name='variable_B',value_name='value_B')
# Out:
#    A variable_B  value_B
# 0  a          B        1
# 1  b          B        3
# 2  c          B        5

# %%
# pivot function
df_pivot = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
                   'baz': [1, 2, 3, 4, 5, 6],
                   'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
df_pivot
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %%
# pivot -> index= should be unique
df_pivot.pivot(columns='bar',index='baz')
# Out:
#      foo            zoo
# bar    A    B    C    A    B    C
# baz
# 1    one  NaN  NaN    x  NaN  NaN
# 2    NaN  one  NaN  NaN    y  NaN
# 3    NaN  NaN  one  NaN  NaN    z
# 4    two  NaN  NaN    q  NaN  NaN
# 5    NaN  two  NaN  NaN    w  NaN
# 6    NaN  NaN  two  NaN  NaN    t

# %%
df_pivot.pivot(columns='foo',index='baz', values='zoo')
# Out:
# foo  one  two
# baz
# 1      x  NaN
# 2      y  NaN
# 3      z  NaN
# 4    NaN    q
# 5    NaN    w
# 6    NaN    t

# %%
df_pivot.pivot(columns='foo',index='baz')['bar']
# Out:
# foo  one  two
# baz
# 1      A  NaN
# 2      B  NaN
# 3      C  NaN
# 4    NaN    A
# 5    NaN    B
# 6    NaN    C

# %%
# pivot_table
df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                         "bar", "bar", "bar", "bar"],
                   "B": ["one", "one", "one", "two", "two",
                         "one", "one", "two", "two"],
                   "C": ["small", "large", "large", "small",
                         "small", "large", "small", "small",
                         "large"],
                   "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                   "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
df.pivot_table(index=['A'], columns='C', values='D', aggfunc='sum')
# Out:
# C    large  small
# A
# bar     11     11
# foo      4      7

# %%
df.pivot_table(index=['A'], columns='C', values='E', aggfunc='sum')
# Out:
# C    large  small
# A
# bar     15     17
# foo      9     13

# %%
# cut method -> can be used to convert numerical variables to categorical variables
# syntax: pd.cut(series or 1-d array, bins=[], labels=[] )
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
df["D"]=pd.cut(df["D"], 3, labels=['low','medium','high'])

# %%
df
# Out:
#      A    B      C       D  E
# 0  foo  one  small     low  2
# 1  foo  one  large     low  4
# 2  foo  one  large     low  5
# 3  foo  two  small     low  5
# 4  foo  two  small     low  6
# 5  bar  one  large  medium  6
# 6  bar  one  small  medium  8
# 7  bar  two  small    high  9
# 8  bar  two  large    high  9

# %%
df=df.astype({'D':object})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       9 non-null      object
#  1   B       9 non-null      object
#  2   C       9 non-null      object
#  3   D       9 non-null      object
#  4   E       9 non-null      int64
# dtypes: int64(1), object(4)
# memory usage: 488.0+ bytes

# %%
# pd.qcut() will discretize based on quantile
